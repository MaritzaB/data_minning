# %% [markdown]
# Instituto Politécnico Nacional
#
# Centro de Investigación en Computación
#
# Minería de datos I
#
# Ejercicios del capítulo 5.
# Ejercicios del 1,3,4,5,6,8,10 y 17.
#
# Presenta: Ana Maritza Bello
#
# ---

# %% [markdown]
# 1.Supongamos que un cuboide base de 10-D contiene sólo tres celdas de base:
#
# 1. *(a1, d2, d3, d4,..., d9, d10)*,
# 1. *(d1, b2, d3, d4,... , d9 , d10 )*
# 1. *(d1, d2 , c3 , d4 , . . . , d9 , d10 )*
#
# donde *a1 != d1 , b2 != d2* y *c3 != d3*. La medida del cubo es `count()`.
#
# (a) ¿Cuántos cuboides no vacíos contendrá un cubo de datos completo?
#
# Respuesta: Ya que el cuboide base es de 10-D, entonces el cubo de datos completo
# tendrá 2^10 = 1024 cuboides no vacíos.
#
#
# (b) ¿Cuántas celdas agregadas no vacías (es decir, no base) contendrá un cubo
# completo?
#
# Respuesta: Cada celda genera 2^10 - 1 celdas agregadas no vacías, por lo tanto
# el cubo completo debeía de tener un total de _3 * 2^10 - 3_ celdas con overlap
# removido.
#
# Tenemos entonces _3*2^7_ celdas traslapadas una vez y _1*2^7_ celdas traslapadas
# dos veces. Por lo tanto debemos remover en total 5*2^7 celdas.
#
# Finalmente, el cubo completo debe tener un total de _3 * 8 * 2^7 - 5 * 2^7 - 3 =
# 19 * 2^7 -3_ celdas agregadas no vacías.
#
# (c) ¿Cuántas celdas agregadas no vacías contendrá un cubo de iceberg si la
# condición del cubo de iceberg es `count ≥ 2`?
#
# Respuesta: *(*, *, d3, d4, ..., d9, d10)* tiene un `count=2` dado que se genera
# por la celda 1 y la celda 2. De igual manera *( *, d2, *, d4, ..., d9, d10)*:2,
# *( *, *, d3, d4, ..., d9, d10)*:2 y *( *, *, *, d4, ..., d9, d10)*:3; entonces se
# tiene *4 * 2^7= 2^9*
#
# (d) Una celda, _c_, es una celda cerrada si no existe ninguna celda, _d_, de
# manera que _d_ es una especialización de la celda _c_ (es decir, _d_ se obtiene
# reemplazando _a ∗_ en _c_ por un valor que no es _∗_) y _d_ tiene el mismo valor
# de medida que _c_. Un cubo cerrado es un cubo de datos que consta únicamente de
# celdas cerradas. ¿Cuántas celdas cerradas hay en el cubo completo?
#
# Respuesta: Existen 7 celdas cerradas, conformadas de la siguiente manera:
#
# 1. (a1 , d2 , d3 , d4 , . . . , d9 , d10 ) : 1,
# 2. (d1 , b2 , d3 , d4 , . . . , d9 , d10 ) : 1,
# 3. (d1 , d2 , c3 , d4 , . . . , d9 , d10 ) : 1,
# 4. (∗, ∗, d3 , d4 , . . . , d9 , d10 ) : 2,
# 5. (∗, d2 , ∗, d4 , . . . , d9 , d10 ) : 2,
# 6. (d1 , ∗, ∗, d4 , . . . , d9 , d10 ) : 2,
# 7. (∗, ∗, ∗, d4 , . . . , d9 , d10 ) : 3.

# %% [markdown]
# 5.3 Supongamos que un cubo de datos, _C_, tiene _D_ dimensiones y el cuboide
# base contiene _k_ tuplas distintas.
#
# (a) Presente una fórmula para calcular el número mínimo de celdas que puede
# contener el cubo _C_.
#
# (b) Presente una fórmula para calcular el número máximo de celdas que _C_ puede
# contener.
#
# (c) Responda los incisos (a) y (b) como si el conteo en cada celda del cubo
# debiera ser no menor que un umbral, _v_.
#
# (d) Responda las partes (a) y (b) como si solo se consideraran celdas cerradas (con el umbral mínimo de conteo, _v_).

# %% [markdown]
# 5.4 Supongamos que un cuboide base tiene tres dimensiones, _A, B, C,_ con el
# siguiente número de celdas: `|A| = 1.000.000`, `|B| = 100` y `|C| = 1000`.
# Supongamos que cada dimensión se divide uniformemente en 10 porciones para
# _fragmentar_.
#
# (a) Suponiendo que cada dimensión tiene un solo nivel, dibuje el cubo completo.
#
# ![image.png](attachment:image.png)
#
# (b) Si cada celda del cubo almacena una medida con cuatro bytes, ¿cuál es el
# tamaño total del cubo calculado si el cubo es _denso_?
#
# Respuesta: El tamaño completo del cubo quedaría de la siguiente manera:
# - *nodo base*: 1
#
# - *nodos de nivel 1*: `A`: 1,000,000, `B`: 100, `C`: 1,000. Total en nivel 1:
#   1,101,100
#
# - *nodos de nivel 2*: `AB`: 100,000,000, `AC`: 1,000,000,000 y `BC`: 100,000.
#   Total en nivel 2: 1,100,100,000
#
# - *nodos de nivel 3*: `ABC`: 100,000,000,000. Total en nivel 3: 100,000,000,000
#
# Si cada celda almacena una medida con 4 bytes, entonces el tamaño total del cubo
# sería de 404,404,404,404 bytes, es decir, *404.4 GB*.
#
# (c) Indique el orden para calcular los fragmentos del cubo que requieren la
# menor cantidad de espacio y calcule la cantidad total de espacio de memoria
# principal necesaria para calcular los planos _2-D_.
#
# Respuesta: El orden para calcular los fragmentos del cubo que requieren la menor
# cantidad de espacio es el siguiente:
#
# ![image-2.png](attachment:image-2.png)
#
# El tamaño total de memoria principal necesaria para calcular los planos 2-D es:
#
# Para el plano completo `BC`: 100*1,000
# Para una columna del plano `AB`: 1,000,000*10
# Para el fragmento del plano `AC`: 100*100,000
#
# Siendo un total de 20,100,000 celdas, que ocupan 80,400,000 bytes, es decir,
# 80.4 MB.

# %% [markdown]
# 5.5 A menudo, el valor de `count` agregado de muchas celdas en un gran cuboide de datos es cero, lo que da como resultado una matriz multidimensional enorme, aunque escasa.
#
# (a) Diseñe un método de implementación que pueda superar elegantemente este
# problema de matriz dispersa. Tenga en cuenta que debe explicar sus estructuras
# de datos en detalle y discutir el espacio necesario, así como también cómo
# recuperar datos de sus estructuras.
#
# Respuesta:
#
# _Paso 1_: Particionar el cubo en subcubos de tamaño fijo. Cada subcubo en
# principio debería de caber en memoria principal disponible para el cálculo del
# cubo. Cada subcubo se debe de comprimir, es decir, se debe de eliminar las
# celdas que no contienen datos válidos, y se guarda en disco.
#
# _Paso 2_: Se debe de construir un índice para cada subcubo. En este segundo paso
# se deben calcular los valores agregados "visitando" cada calda del cubo en un
# orden que minimice el número de veces que cada celda deba de ser revisada. Al
# clasificar y calcular primero los planos del cubo de datos según su tamaño en
# orden ascendente, se puede mantener un plano más pequeño en la memoria principal
# mientras se recupera y calcula sólo un fragmento a la vez para un plano más
# grande.
#
# (b) Modifique su diseño en (a) para manejar actualizaciones de datos
# incrementales. Da el razonamiento detrás de tu nuevo diseño.
#
# Respuesta: Con el fin de manejar actualizaciones de datos incrementales, se
# puede usar el método antes mencionado. Solo en el caso de que hayan
# actualizaciones en una partición se debe de volver a calcular el cuboide, así
# solo actualizamos este cuboide sin que todo el cubo se tenga que volver a
# calcular. Posteriormente se propagan las actualizaciones de este fragmento a los
# demás cuboides que lo contienen.

# %% [markdown]
# 5.6 Al calcular un cubo de alta dimensionalidad, nos encontramos con la _maldición inherente del problema de dimensionalidad_: existe una gran cantidad de subconjuntos de combinaciones de dimensiones.
#
# (a) Suponga que hay sólo dos celdas base, `{(a1, a2, a3,..., a100), (a1, a2,b3,..., b100)}`,
# en un cuboide de base de `100-D`. Calcule el número de celdas agregadas no
# vacías. Comente el espacio de almacenamiento y el tiempo necesarios para
# calcular estas celdas.
#
# Respuesta: Dado que cada celda base genera 2^100 celdas agregadas no vacías, las
# dos celdas base generan _2 * (2^100)  = 2^101 -2_ celdas con valores agregados.
# Como las celdas `a1, a2` se repiten 4 veces, entonces el número de celdas está
# dado por _2^101 - 2 - 4 = 2^101 - 6_.
#
# (b) Supongamos que vamos a calcular un cubo de iceberg a partir de (a). Si el
# número mínimo de soportes en la condición del iceberg es 2, ¿cuántas celdas
# agregadas habrá en el cubo del iceberg? Muestra las celdas.
#
# Solo estáran las celdas donde `a1, a2` se repiten 4 veces. Es decir:
# ${(a1 , a2 , ∗, . . . , ∗), (a1 , ∗, ∗, . . . , ∗), (∗, a2 , ∗, . . . , ∗), (∗, ∗, ∗, . . . , ∗)}$
#
# (c) La introducción de cubos de iceberg reducirá la carga de calcular celdas
# agregadas triviales en un cubo de datos. Sin embargo, incluso con cubos de
# iceberg, podríamos terminar teniendo que calcular una gran cantidad de celdas
# triviales y poco interesantes (es decir, con recuentos pequeños). Supongamos que
# una base de datos tiene **20** tuplas que se asignan (o cubren) las dos
# siguientes celdas base en un cuboide de base `100-D`, cada una con un recuento
# de celdas de 10: `{(a1, a2, a3,..., a100): 10, (a1, a2, b3,..., b100): 10}`.
#
# Respuesta: Solo se contarán los conjuntos que contengas a `a`, por lo tanto
# serán: $2^{101} - 6$
#
# i. Sea el soporte mínimo **10**. ¿Cuántas celdas agregadas distintas habrá como las siguientes: `{(a1, a2, a3, a4,..., a99, ∗): 10,. . . , (a1 , a2 , ∗ , a4 , . . . , a99 , a100 ) : 10, . . . , (a1 , a2 , a3 , ∗ , . . . , ∗ , ∗ ) : 20}`?
#
# ii. Si ignoramos todas las celdas agregadas que se pueden obtener reemplazando
# algunas constantes con _*_ mientras mantenemos el mismo valor de medida,
# ¿cuántas celdas distintas quedan? ¿Cuáles son las celdas?
#
# Respuesta: Hay solo 3 celdas distintas faltantes: `{(a1, a2, ∗, a4,..., a99,
# a100): 10, (a1, a2, b3, ∗,..., b99, b100): 10, (a1, a2, * , *): 10}`

# %% [markdown]
# 5.8 Supongamos que queremos calcular un cubo de iceberg para las dimensiones *A,
# B, C, D*, donde deseamos materializar todas las celdas que satisfacen un
# recuento mínimo de soporte de al menos _v_, y donde _cardinalidad(A) <
# cardinalidad(B) < cardinalidad(C) < cardinalidad(D)_. Muestre el árbol de
# procesamiento *BUC* (que muestra el orden en el que el algoritmo *BUC* explora
# la red de un cubo de datos, comenzando por todos) para la construcción de este
# cubo iceberg.
#
# Respuesta: Las dimensiones deben de ser procesadas en orden de cardinalidad
# decreciente, estó es discriminar primero las dimensiones con mayor cardinalidad
# con el fin de acortar el espacio de búsqueda tan rápido como sea posible. En
# este caso sería en el orden `D, C, B, A`.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5.10 Un almacén de datos de vuelo para un agente de viajes consta de seis dimensiones: *viajero, salida (ciudad), hora de salida, llegada, hora de llegada y vuelo*; y dos medidas: `count()` y `avg_fare()`, donde `avg_fare()` almacena la tarifa concreta en el nivel más bajo pero la tarifa promedio en otros niveles.
#
# (a) Suponga que el cubo está completamente materializado. Comenzando con el
# *cuboide base* `[viajero, salida, hora de salida, llegada, hora de llegada,
# vuelo]`, ¿qué operaciones OLAP específicas (por ejemplo, vuelo acumulado a
# aerolínea) se deben realizar para enumerar la tarifa promedio por mes para cada
# viajero de negocios que vuela con American Airlines _(AA)_ desde Los Ángeles en
# 2009?
#
# Respuesta: Las operaciones OLA específicas que se deben de realizar son las
# siguientes:
#
# - Roll-up: de `viajero` a `categoría` y particionar en `bussines`
#
# - Roll-up: de `salida` a `ciudad` y particionar en `Los Angeles`
#
# - Roll-up: de `hora de salida` a `año` y particionar en `2009`
#
# - Roll-up: de `llegada` a `*`
#
# - Roll-up: de `hora de llegada` a `*`
#
# - Roll-up de `vuelo` a `aerolínea` y particionar en `AA`
#
# - Drill-down de `viajero` a `*`
#
# - Drill-down de `hora de salida` a `mes`
#
# (b) Supongamos que queremos calcular un cubo de datos donde la condición es que
# el número mínimo de registros sea 10 y la tarifa promedio sea superior a $500.
# Describa un método eficiente de cálculo de cubos (basado en el sentido común
# sobre la distribución de datos de vuelo).
#
# Podemos calcular el Iceberg cube con el algoritmo de H-Tree.

# %% [markdown]
# 5.17 La exploración de cubos basada en el *descubrimiento* es una forma deseable
# de marcar puntos interesantes entre un gran número de celdas en un cubo de
# datos. Los usuarios individuales pueden tener diferentes puntos de vista sobre
# si un punto debe considerarse lo suficientemente interesante como para marcarlo.
# Supongamos que uno desea marcar aquellos objetos cuyo valor absoluto de
# *puntuación z (z score)* es superior a 2 en cada fila y columna en un plano
# dimensional `d`.
#
# (a) Obtenga un método de cálculo eficiente para identificar dichos puntos
# durante el cálculo del cubo de datos.
#
# En una primera instancia, deberíamos de calcular los valores agregados con los
# que posteriormente se pueda calcular el z-score (`count, sum, sum^2`). Una vez
# que se tengan estos valores, se puede calcular el z-score.
