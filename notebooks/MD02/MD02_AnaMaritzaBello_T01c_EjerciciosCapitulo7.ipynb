# %% [markdown]
# Instituto Politécnico Nacional
#
# Centro de Investigación en Computación
#
# Minería de datos I
#
# Ejercicios del capítulo 7.
#
# Ejercicios 1, 2, 3, 9 y 11.
#
# Presenta: Ana Maritza Bello
#
# ---

# %% [markdown]
# 7.1 Proponer y delinear un enfoque de minería de niveles compartidos para
# extraer reglas de asociación multinivel en las que cada elemento esté codificado
# por su posición de nivel. Diseñelo de modo que un escaneo inicial de la base de
# datos recopile el recuento de cada elemento en cada nivel de concepto,
# identificando elementos frecuentes y subfrecuentes. Comente sobre el costo de
# procesamiento de extraer asociaciones multinivel con este método en comparación
# con la extracción de asociaciones de un solo nivel.
#
# **Respuesta**
#
# Dando como ejemplo el siguiente conjunto de transacciones:
#
# ![image.png](attachment:image.png)
#
# 1 Escaneo Inicial:
# Durante el escaneo, se crea una tabla de transacciones T codificada con información jerárquica.
# Ejemplo de codificación: "electronicos-computadora-laptop" se codifica como '121', donde '1' representa "Electronicos" en el nivel-1, '2' representa "Computadoras" en el nivel-2, y '1' representa "Laptops" en el nivel-3.
# Se acumulan los recuentos de soporte de cada elemento en cada nivel.
#
# 2 Generación de Conjuntos de Candidatos Multinivel:
#
#     - Se encuentran los 1-itemsets frecuentes (L1) en todos los niveles.
#
#     - Se unen para generar los candidatos 2-itemsets, y se escanea T para determinar cuáles son frecuentes.
#
#     - Se repite el proceso para generar candidatos 3-itemsets y así sucesivamente
# hasta que ningún nivel genere nuevos candidatos.
#
# 2.1 Aplicación del Algoritmo Apriori:
# Este enfoque sigue esencialmente el algoritmo Apriori para generar y verificar
# candidatos de manera iterativa.
#
# 3. Generación de Reglas:
# Una vez se encuentran todos los itemsets frecuentes, se generan reglas de
# asociación multinivel.
#
# 4. Costo de Procesamiento:
#
# 4.1 Ventajas: Eficiencia en escaneo de bases de datos: El escaneo de la tabla
# codificada tiene un costo similar al de las asociaciones de un solo nivel.
#
# 4.2 Desventajas: Ineficiencia en generación de candidatos: La generación de
# todos los candidatos en cada iteración para todos los niveles aumenta la
# complejidad computacional.  Mayor costo en comparación con asociaciones de un
# solo nivel: La generación de candidatos para este método es más costosa que para
# las asociaciones de un solo nivel, ya que se deben generar todos los conjuntos
# candidatos para todos los niveles.
#
# 5. Comparación con la Extracción de Asociaciones de un Solo Nivel: Eficiencia en
# escaneo de base de datos: Similar para ambas metodologías.  Ineficiencia en
# generación de candidatos: Este método es menos eficiente, ya que genera
# candidatos para todos los niveles en cada iteración.  Este enfoque ofrece una
# visión detallada de las asociaciones multinivel, utilizando un ejemplo diferente
# centrado en productos electrónicos y computadoras. La comparación con la minería
# de asociaciones de un solo nivel destaca la necesidad de optimización en la
# generación de candidatos para mejorar la eficiencia del método propuesto.

# %% [markdown]
# 7.2 Supongamos que, como gerente de una cadena de tiendas, desea utilizar datos
# transaccionales de ventas para analizar la efectividad de los anuncios de su
# tienda. En particular, le gustaría estudiar cómo influyen factores específicos
# en la eficacia de los anuncios que anuncian una categoría particular de
# artículos en oferta. Los factores a estudiar son la región en la que viven los
# clientes y el día de la semana y hora del día de los anuncios. Analice cómo
# diseñar un método eficiente para extraer los conjuntos de datos de transacciones
# y explique cómo los métodos de minería multidimensional y multinivel pueden
# ayudarlo a obtener una buena solución.
#
# **Respuesta**
#
#  La minería multidimensional permite analizar los efectos de las campañas publicitarias en relación con diversos factores, como la región, el día y la hora de los anuncios. Además, la minería multilevel resulta valiosa, especialmente al considerar las ubicaciones.
#
# En este escenario complejo, se debe tener en cuenta lo siguiente para diseñar un método eficiente:
#
# 1. Predicados Utilizados:
#
# Se deben considerar los predicados (dimensiones) de compra, ubicación y tiempo.
#
# 2. Soporte Reducido en Niveles Inferiores de la Jerarquía de Ubicación:
#
# 3. Algoritmos eficientes deben emplear un soporte reducido en niveles inferiores
#    de la jerarquía de ubicación, ya que cada tienda en una región puede no
#    representar una parte lo suficientemente grande de las ventas regionales
#    totales para que un conjunto de k-predicados se vuelva frecuente.
#
# Enfoque en Reglas de Asociación Interdimensionales:
#
# Dado que solo estamos interesados en reglas de asociación interdimensionales, no es necesario preocuparse por predicados repetidos.
#
# En este contexto, un algoritmo basado en cubos de datos que mine en cada nivel
# de las jerarquías de conceptos múltiples mencionadas anteriormente debería
# identificarse como una solución eficiente. Este enfoque permitirá la extracción
# de patrones que reflejen la efectividad de las campañas publicitarias dirigidas.
# Además, la minería multilevel puede revelar patrones efectivos a niveles más
# detallados, indicando la eficacia de los anuncios para ciertos productos en
# ubicaciones específicas. Este conocimiento puede ser ayudarnos a definir nuevas
# regiones y optimizar las estrategias publicitarias para obtener mayores
# beneficios.

# %% [markdown]
# 7.3 Las reglas de asociación cuantitativa pueden revelar comportamientos excepcionales dentro de un conjunto de datos, donde "excepcional" puede definirse con base en la teoría estadística. Por ejemplo, la Sección 7.2.3 muestra la regla de asociación.
#
# $$ sexo = mujer ⇒ salario_medio = \$7.90/h (salario_medio_general = \$9.02/h ) $$
#
# lo que sugiere un patrón excepcional. La norma establece que el salario medio de
# las mujeres es de sólo 7.90 dólares por hora, lo que es un salario
# significativamente más bajo que el promedio general de 9.02 dólares por hora.
# Analice cómo se pueden descubrir dichas reglas cuantitativas de manera
# sistemática y eficiente en grandes conjuntos de datos con atributos
# cuantitativos.
#
# **Respuesta**
#
# Para descubrir reglas cuantitativas basadas en medias de manera eficiente, se pueden incorporar las siguientes ideas generales, complementando el enfoque anterior:
#
# Mejoras en la Eficiencia del Proceso:
# 1. Utilización de Algoritmos de Minería de Conjuntos Frecuentes:
# Inicialmente, se pueden emplear algoritmos como Apriori o FP-growth para encontrar todos los conjuntos frecuentes de elementos categóricos en la base de datos.
# 2. Para cada conjunto frecuente, podemos calcular la media de los atributos cuantitativos utilizando la estructura de datos de árbol hash presentada por Agrawal y Srikant. Este enfoque permite realizar este cálculo en una sola pasada sobre la base de datos, optimizando el tiempo de procesamiento.
# 3. Encontrar todas las reglas y subreglas no contenidas. Para cada conjunto frecuente X y atributo cuantitativo e, verifica si la regla X ⇒ Mean(e)(T_X) cumple con la significancia estadística.
# 4. Incorpora métodos específicos para manejar atributos cuantitativos en la identificación de reglas no contenidas, asegurando la precisión y relevancia de las asociaciones descubiertas.

# %% [markdown]
# 7.9 La sección 7.5.1 definió una medida de distancia de patrón entre los patrones cerrados P1 y P2 como
#
# $$ Pat\_Dist(P_1 , P_2) = 1 - \frac{|T(P_1) \cap T(P_2)|}{|T(P_1) \cup T(P_2)|}$$
#
# donde _T(P1)_ y _T(P2)_ son los conjuntos de transacciones de soporte de _P1_ y
# _P2_, respectivamente. ¿Es esta una métrica de distancia válida? Muestra la
# derivación para respaldar tu respuesta.
#
# **Respuesta**
#
# Para que una función de distancia sea válida, debe cumplir con las siguientes
# propiedades:
#
# 1. No negatividad: $$ d(x,y) \geq 0 $$
# 2. Identidad de indiscernibles: $$ d(x,y) = 0 \iff x = y $$
# 3. Simetría: $$ d(x,y) = d(y,x) $$
# 4. Desigualdad triangular: $$ d(x,y) \leq d(x,z) + d(z,y) $$
# 5. Desigualdad de Minkowski: $$ d(x,y) \leq d(x,z) + d(z,y) $$
#
# La función de distancia de patrón cumple con las propiedades 1, 2, 3 y 4, por lo
# que es una métrica de distancia válida.

# %% [markdown]
# 7.11 La extracción frecuente de patrones puede generar muchos patrones superfluos. Por lo tanto, es importante desarrollar métodos que extraigan patrones comprimidos. Supongamos que un usuario desea obtener solo k patrones (donde k es un número entero pequeño). Resuma un método eficiente que genere los k patrones más representativos, donde se prefieren patrones más distintos a patrones muy similares. Ilustre la eficacia de su método utilizando un pequeño conjunto de datos.
